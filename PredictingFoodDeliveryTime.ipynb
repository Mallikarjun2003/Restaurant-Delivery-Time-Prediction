# %% [markdown]
# ## FEATURES:
#
# * Restaurant: A unique ID that represents a restaurant.
# * Location: The location of the restaurant.
# * Cuisines: The cuisines offered by the restaurant.
# * Average_Cost: The average cost for one person/order.
# * Minimum_Order: The minimum order amount.
# * Rating: Customer rating for the restaurant.
# * Votes: The total number of customer votes for the restaurant.
# * Reviews: The number of customer reviews for the restaurant.
# * Delivery_Time: The order delivery time of the restaurant. (Target Classes)

# %% [markdown]
# ## Loading The Data

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import re
from tqdm import tqdm

# %%
train = pd.read_excel('C:\\Users\\91868\\OneDrive\\Desktop\\DATA SCIENCE PROJECTS\\New folder\\Data_Train.xlsx')
test = pd.read_excel('C:\\Users\\91868\\OneDrive\\Desktop\\DATA SCIENCE PROJECTS\\New folder\\Data_Test.xlsx')

# %% [markdown]
# ## Dataset Features

# %% [markdown]
# #### Trainig Data

# %%
train.shape
# Out:
# (11094, 9)

# %%
train.columns
# Out:
# Index(['Restaurant', 'Location', 'Cuisines', 'Average_Cost', 'Minimum_Order',
#        'Rating', 'Votes', 'Reviews', 'Delivery_Time'],
#       dtype='object')

# %%
train.head()
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
#
#                                  Cuisines Average_Cost Minimum_Order Rating  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps         ₹200           ₹50    3.5
# 1                     Ice Cream, Desserts         ₹100           ₹50    3.5
# 2         Italian, Street Food, Fast Food         ₹150           ₹50    3.6
# 3          Mughlai, North Indian, Chinese         ₹250           ₹99    3.7
# 4                         Cafe, Beverages         ₹200           ₹99    3.2
#
#   Votes Reviews Delivery_Time
# 0    12       4    30 minutes
# 1    11       4    30 minutes
# 2    99      30    65 minutes
# 3   176      95    30 minutes
# 4   521     235    65 minutes

# %%
train.isnull().sum()
# Out:
# Restaurant       0
# Location         0
# Cuisines         0
# Average_Cost     0
# Minimum_Order    0
# Rating           0
# Votes            0
# Reviews          0
# Delivery_Time    0
# dtype: int64

# %%
train.describe(include = 'all')
# Out:
#        Restaurant                                    Location      Cuisines  \
# count       11094                                       11094         11094
# unique       7480                                          35          2179
# top       ID_7184  Mico Layout, Stage 2, BTM Layout,Bangalore  North Indian
# freq           22                                         947           850
#
#        Average_Cost Minimum_Order Rating  Votes Reviews Delivery_Time
# count         11094         11094  11094  11094   11094         11094
# unique           26            18     33   1103     761             7
# top            ₹200           ₹50      -      -       -    30 minutes
# freq           3241         10118   1191   2074    2312          7406

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11094 entries, 0 to 11093
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Restaurant     11094 non-null  object
#  1   Location       11094 non-null  object
#  2   Cuisines       11094 non-null  object
#  3   Average_Cost   11094 non-null  object
#  4   Minimum_Order  11094 non-null  object
#  5   Rating         11094 non-null  object
#  6   Votes          11094 non-null  object
#  7   Reviews        11094 non-null  object
#  8   Delivery_Time  11094 non-null  object
# dtypes: object(9)
# memory usage: 780.2+ KB

# %% [markdown]
# #### Test Data

# %%
test.shape
# Out:
# (2774, 8)

# %%
test.columns
# Out:
# Index(['Restaurant', 'Location', 'Cuisines', 'Average_Cost', 'Minimum_Order',
#        'Rating', 'Votes', 'Reviews'],
#       dtype='object')

# %%
test.head()
# Out:
#   Restaurant                                    Location  \
# 0    ID_2842  Mico Layout, Stage 2, BTM Layout,Bangalore
# 1     ID_730  Mico Layout, Stage 2, BTM Layout,Bangalore
# 2    ID_4620                             Sector 1, Noida
# 3    ID_5470                  Babarpur, New Delhi, Delhi
# 4    ID_3249                             Sector 1, Noida
#
#                                             Cuisines Average_Cost  \
# 0                    North Indian, Chinese, Assamese         ₹350
# 1                                     Biryani, Kebab         ₹100
# 2                                          Fast Food         ₹100
# 3  Mithai, North Indian, Chinese, Fast Food, Sout...         ₹200
# 4                                 Chinese, Fast Food         ₹150
#
#   Minimum_Order Rating Votes Reviews
# 0           ₹50    4.2   361     225
# 1           ₹50    NEW     -       -
# 2           ₹50    3.6    36      16
# 3           ₹50    3.6    66      33
# 4           ₹50    2.9    38      14

# %%
test.isnull().sum()
# Out:
# Restaurant       0
# Location         0
# Cuisines         0
# Average_Cost     0
# Minimum_Order    0
# Rating           0
# Votes            0
# Reviews          0
# dtype: int64

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2774 entries, 0 to 2773
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Restaurant     2774 non-null   object
#  1   Location       2774 non-null   object
#  2   Cuisines       2774 non-null   object
#  3   Average_Cost   2774 non-null   object
#  4   Minimum_Order  2774 non-null   object
#  5   Rating         2774 non-null   object
#  6   Votes          2774 non-null   object
#  7   Reviews        2774 non-null   object
# dtypes: object(8)
# memory usage: 173.5+ KB

# %%
test.describe(include = 'all')
# Out:
#        Restaurant                   Location      Cuisines Average_Cost  \
# count        2774                       2774          2774         2774
# unique       2401                         35           881           19
# top       ID_1209  D-Block, Sector 63, Noida  North Indian         ₹200
# freq            8                        221           226          820
#
#        Minimum_Order Rating Votes Reviews
# count           2774   2774  2774    2774
# unique             9     30   580     392
# top              ₹50      -     -       -
# freq            2556    305   542     593

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# We will consider the following features of training and test datasets. Here I have grouped the columns based on similarity of values which will make it easy for cleaning.
#
# * Cleaning Average_Cost & Minimum_order columns to remove special characters and make them float variables.
# * Location & Cuisines are categoriacal variables that needs to be cleaned before encoding.
# * Rating, Votes & Reviews needs to be cleaned and converted to respective types.
#
# We will delve deeper in the coming sections.

# %% [markdown]
# #### Average_Cost& Minimum_order

# %%
train.head()
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
#
#                                  Cuisines Average_Cost Minimum_Order Rating  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps         ₹200           ₹50    3.5
# 1                     Ice Cream, Desserts         ₹100           ₹50    3.5
# 2         Italian, Street Food, Fast Food         ₹150           ₹50    3.6
# 3          Mughlai, North Indian, Chinese         ₹250           ₹99    3.7
# 4                         Cafe, Beverages         ₹200           ₹99    3.2
#
#   Votes Reviews Delivery_Time
# 0    12       4    30 minutes
# 1    11       4    30 minutes
# 2    99      30    65 minutes
# 3   176      95    30 minutes
# 4   521     235    65 minutes

# %%
#Finding the unique values in Average_Cost
train['Average_Cost'].unique()
# Out:
# array(['₹200', '₹100', '₹150', '₹250', '₹650', '₹350', '₹800', '₹50',
#        '₹400', '₹600', '₹300', '₹750', '₹450', '₹550', '₹1,000', '₹500',
#        '₹900', '₹1,200', '₹950', '₹850', '₹700', '₹1,150', 'for',
#        '₹1,100', '₹1,400', '₹2,050'], dtype=object)

# %% [markdown]
# The Average_Cost has an invalid value in one of its rows. We will replace it with 200 which is the most frequent value in the column.(Check the train.describe() method). We will add 200 as a string and not as an integer as the column is of type object and all its values are strings.

# %%
train[train['Average_Cost'] == 'for']
# Out:
#      Restaurant         Location   Cuisines Average_Cost Minimum_Order Rating  \
# 6297    ID_6472  Pune University  Fast Food          for           ₹50    NEW
#
#      Votes Reviews Delivery_Time
# 6297     -       -    30 minutes

# %%
#replacing 'for' with 200
train['Average_Cost'].replace('for', '200', inplace = True)

# %% [markdown]
# Now we will clean all the values and will convert it in to integer.

# %%
train['Average_Cost_Cleaned'] = train['Average_Cost'].apply(lambda x: int(re.sub("[^0-9]", "", x)))

# %%
train['Average_Cost_Cleaned'].unique()
# Out:
# array([ 200,  100,  150,  250,  650,  350,  800,   50,  400,  600,  300,
#         750,  450,  550, 1000,  500,  900, 1200,  950,  850,  700, 1150,
#        1100, 1400, 2050], dtype=int64)

# %% [markdown]
# We can see that all the special characters ahave been removed and strings have been converted to integers.
#
# ---
#
# Performing same thing on test data set

# %%
test['Average_Cost'].unique()
# Out:
# array(['₹350', '₹100', '₹200', '₹150', '₹300', '₹50', '₹250', '₹500',
#        '₹650', '₹400', '₹550', '₹450', '₹600', '₹750', '₹850', '₹1,000',
#        '₹700', '₹800', '₹1,200'], dtype=object)

# %%
test['Average_Cost_Cleaned'] = test['Average_Cost'].apply(lambda x: int(re.sub("[^0-9]", "", x)))

# %%
test['Average_Cost_Cleaned'].unique()
# Out:
# array([ 350,  100,  200,  150,  300,   50,  250,  500,  650,  400,  550,
#         450,  600,  750,  850, 1000,  700,  800, 1200], dtype=int64)

# %% [markdown]
# Now lets do the same for Minimum_Order column

# %%
train['Minimum_Order'].unique()
# Out:
# array(['₹50', '₹99', '₹0', '₹200', '₹450', '₹350', '₹79', '₹400', '₹199',
#        '₹500', '₹250', '₹150', '₹90', '₹299', '₹300', '₹240', '₹89',
#        '₹59'], dtype=object)

# %%
train['Minimum_Order_Cleaned'] = train['Minimum_Order'].apply(lambda x: int(re.sub("[^0-9]", "", x)))

# %%
test['Minimum_Order'].unique()
# Out:
# array(['₹50', '₹99', '₹500', '₹0', '₹200', '₹149', '₹199', '₹399', '₹89'],
#       dtype=object)

# %%
test['Minimum_Order_Cleaned'] = test['Minimum_Order'].apply(lambda x: int(re.sub("[^0-9]", "", x)))

# %%
train.head()
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
#
#                                  Cuisines Average_Cost Minimum_Order Rating  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps         ₹200           ₹50    3.5
# 1                     Ice Cream, Desserts         ₹100           ₹50    3.5
# 2         Italian, Street Food, Fast Food         ₹150           ₹50    3.6
# 3          Mughlai, North Indian, Chinese         ₹250           ₹99    3.7
# 4                         Cafe, Beverages         ₹200           ₹99    3.2
#
#   Votes Reviews Delivery_Time  Average_Cost_Cleaned  Minimum_Order_Cleaned
# 0    12       4    30 minutes                   200                     50
# 1    11       4    30 minutes                   100                     50
# 2    99      30    65 minutes                   150                     50
# 3   176      95    30 minutes                   250                     99
# 4   521     235    65 minutes                   200                     99

# %% [markdown]
# #### Location & CUISINES

# %% [markdown]
# Location and Cuisines are categorical variables that need to be encoded later. By looking at the dataset, we can see that each of these columns have multiple values in them. We can use each of them as a feature by splitting each column into 'n' number of features.
# To do that we will first find the maximum number(n) of features a column has in the entire dataset including both test and train data. Once the maximum number of features within a cell is found, we will split all the rows in the dataset for that specific column into n features.

# %%
def max_features_in_single_row(train, test, delimiter):
    max_info = 0
    item_lis = list(train) + list(test)  # Concatenate train and test Series into a single list
    for i in item_lis:
        if len(i.split("{}".format(delimiter))) > max_info:
            max_info = len(i.split("{}".format(delimiter)))
    print("\n", "-"*35)
    print("Max_Features in One Observation = ", max_info)
    return max_info

# %%
def feature_splitter(feat, name, delimiter, max_info):
    # Initialize a dictionary to store extracted features
    extracted_features = {}
    for i in range(max_info):
        extracted_features['{}_Feature_{}'.format(name, i+1)] = []

    print("-"*35)
    print("Features Dictionary : ", extracted_features)

    # Iterate over each element in the Series
    for item in tqdm(feat):
        # Split the item based on the delimiter and process each split
        splits = item.split("{}".format(delimiter))
        for j in range(max_info):
            try:
                extracted_features['{}_Feature_{}'.format(name, j+1)].append(splits[j].lower().strip())
            except IndexError:
                extracted_features['{}_Feature_{}'.format(name, j+1)].append(np.nan)

    return extracted_features

# %%
delimiter = ','

# Determine the maximum number of features in a single cell across train and test data
loc_max = max_features_in_single_row(train['Location'], test['Location'], delimiter)

# Splitting Location column based on the determined maximum number of features
train_Location_splits = feature_splitter(train['Location'], 'Location', delimiter, loc_max)
test_Location_splits = feature_splitter(test['Location'], 'Location', delimiter, loc_max)

print(train_Location_splits)
print(test_Location_splits)
# Out:
#  -----------------------------------
# Max_Features in One Observation =  4
# -----------------------------------
# Features Dictionary :  {'Location_Feature_1': [], 'Location_Feature_2': [], 'Location_Feature_3': [], 'Location_Feature_4': []}
# 100%|████████████████████████████████████████████████████████████████████████| 11094/11094 [00:00<00:00, 141358.70it/s]
# -----------------------------------
# Features Dictionary :  {'Location_Feature_1': [], 'Location_Feature_2': [], 'Location_Feature_3': [], 'Location_Feature_4': []}
# 100%|██████████████████████████████████████████████████████████████████████████| 2774/2774 [00:00<00:00, 141646.67it/s]
# {'Location_Feature_1': ['fti college', 'sector 3', 'mumbai central', 'sector 1', 'rmz centennial', 'rmz centennial', 'mumbai central', 'delhi university-gtb nagar', 'delhi university-gtb nagar', 'sector 1', 'mumbai central', 'yerawada', 'sector 1', 'delhi university-gtb nagar', 'delhi administration flats', 'moulali', 'sector 1', 'dockyard road', 'pune university', 'gora bazar', 'd-block', 'sector 14', 'd-block', 'd-block', 'sector 3', 'mico layout', 'd-block', 'mumbai central', 'dockyard road', 'sector 1', 'gora bazar', 'd-block', 'fti college', 'd-block', 'laxman vihar industrial area', 'sector 1', 'pune university', 'moulali', 'delhi university-gtb nagar', 'tiretti', 'sandhurst road', 'mumbai central', 'mg road', 'hyderabad public school', 'tiretti', 'majestic', 'd-block', 'mico layout', 'delhi university-gtb nagar', 'delhi university-gtb nagar', 'fti college', 'fti college', 'sandhurst road', 'mg road', 'sector 1', 'chandni chowk', 'mg road', 'delhi university-gtb nagar', 'mico layout', 'delhi administration flats', 'mg road', 'sector 1', 'yerawada', 'sector 3', 'sector 1', 'sector 14', 'dockyard road', 'mico layout', 'delhi high court', 'mumbai central', 'rmz centennial', 'd-block', 'sector 1', 'moulali', 'majestic', 'chandni chowk', 'delhi administration flats', 'rmz centennial', 'delhi university-gtb nagar', 'sector 14', 'sandhurst road', 'd-block', 'd-block', 'sector 14', 'mg road', 'sector 1', 'mg road', 'd-block', 'rmz centennial', 'chatta bazaar', 'sandhurst road', 'sector 63a', 'mico layout', 'rmz centennial', 'mumbai central', 'd-block', 'delhi high court', 'd-block', 'delhi university-gtb nagar', 'delhi cantt.', 'sector 3', 'pune university', 'mico layout', 'majestic', 'fti college', 'dockyard road', 'tejas nagar colony', 'd-block', 'delhi administration flats', 'sector 14', 'mg road', 'mico layout', 'sector 14', 'fti college', 'mg road', 'fti college', 'babarpur', 'rmz centennial', 'sector 3', 'mico layout', 'rmz centennial', 'd-block', 'delhi cantt.', 'nathan road', 'mico layout', 'laxman vihar industrial area', 'laxman vihar industrial area', 'laxman vihar industrial area', 'mico layout', 'mg road', 'd-block', 'd-block', 'mico layout', 'delhi high court', 'mumbai central', 'sector 1', 'mumbai central', 'd-block', 'pune university', 'laxman vihar industrial area', 'rmz centennial', 'yerawada', 'sector 1', 'fti college', 'd-block', 'panjetan colony', 'pune university', 'delhi administration flats', 'delhi university-gtb nagar', 'mico layout', 'yerawada', 'pune university', 'delhi high court', 'laxman vihar industrial area', 'rmz centennial', 'sector 1', 'yerawada', 'mumbai central', 'sector 63a', 'sector 1', 'sector 1', 'mumbai central', 'moulali', 'tiretti', 'raja bazar', 'd-block', 'laxman vihar industrial area', 'delhi high court', 'yerawada', 'delhi cantt.', 'yerawada', 'fti college', 'fti college', 'rmz centennial', 'babarpur', 'dockyard road', 'mumbai central', 'sector 1', 'laxman vihar industrial area', 'delhi cantt.', 'mumbai central', 'rmz centennial', 'laxman vihar industrial area', 'nathan road', 'tejas nagar colony', 'dockyard road', 'delhi university-gtb nagar', 'pune university', 'pune university', 'laxman vihar industrial area', 'tiretti', 'mico layout', 'rmz centennial', 'dockyard road', 'raja bazar', 'mumbai central', 'pune university', 'yerawada', 'sector 1', 'delhi university-gtb nagar', 'tiretti', 'laxman vihar industrial area', 'mico layout', 'mico layout', 'd-block', 'delhi high court', 'panjetan colony', 'd-block', 'd-block', 'sector 3', 'mumbai central', 'mg road', 'mumbai central', 'mico layout', 'mico layout', 'sector 63a', 'delhi university-gtb nagar', 'fti college', 'jaya nagar', 'sector 63a', 'majestic', 'sector 1', 'rmz centennial', 'sandhurst road', 'majestic', 'nathan road', 'delhi administration flats', 'laxman vihar industrial area', 'pune university', 'mg road', 'd-block', 'dockyard road', 'mico layout', 'raja bazar', 'sector 3', 'babarpur', 'sector 1', 'raja bazar', 'mumbai ce ...
# {'Location_Feature_1': ['mico layout', 'mico layout', 'sector 1', 'babarpur', 'sector 1', 'yerawada', 'raja bazar', 'sector 3', 'sector 1', 'd-block', 'delhi university-gtb nagar', 'd-block', 'sector 1', 'delhi high court', 'btm layout 1', 'sector 14', 'd-block', 'laxman vihar industrial area', 'fti college', 'sandhurst road', 'sector 1', 'sector 14', 'd-block', 'yerawada', 'mico layout', 'fti college', 'fti college', 'nathan road', 'fti college', 'd-block', 'majestic', 'babarpur', 'dockyard road', 'nathan road', 'delhi university-gtb nagar', 'delhi cantt.', 'delhi university-gtb nagar', 'sandhurst road', 'sector 1', 'sector 1', 'sector 14', 'fti college', 'delhi high court', 'mumbai central', 'sandhurst road', 'tiretti', 'nathan road', 'mico layout', 'sector 63a', 'nathan road', 'delhi high court', 'nathan road', 'majestic', 'fti college', 'rmz centennial', 'sector 14', 'sector 1', 'rmz centennial', 'mg road', 'delhi high court', 'mico layout', 'majestic', 'majestic', 'fti college', 'mico layout', 'nathan road', 'laxman vihar industrial area', 'tejas nagar colony', 'sector 63a', 'd-block', 'sector 63a', 'babarpur', 'mg road', 'rmz centennial', 'delhi cantt.', 'rmz centennial', 'yerawada', 'fti college', 'mg road', 'delhi university-gtb nagar', 'raja bazar', 'sector 3', 'delhi high court', 'd-block', 'majestic', 'moulali', 'd-block', 'mico layout', 'mumbai central', 'sector 1', 'mico layout', 'sector 63a', 'btm layout 1', 'fti college', 'rmz centennial', 'delhi university-gtb nagar', 'd-block', 'dockyard road', 'delhi administration flats', 'laxman vihar industrial area', 'delhi administration flats', 'dockyard road', 'mg road', 'majestic', 'fti college', 'sandhurst road', 'sector 14', 'delhi administration flats', 'chandni chowk', 'sector 14', 'mico layout', 'mumbai central', 'laxman vihar industrial area', 'sector 1', 'd-block', 'sandhurst road', 'delhi university-gtb nagar', 'sector 3', 'yerawada', 'yerawada', 'sandhurst road', 'delhi administration flats', 'dockyard road', 'fti college', 'laxman vihar industrial area', 'sector 3', 'delhi cantt.', 'fti college', 'delhi high court', 'sector 14', 'musi nagar', 'fti college', 'nathan road', 'yerawada', 'mico layout', 'sector 1', 'delhi high court', 'sector 1', 'mico layout', 'babarpur', 'delhi university-gtb nagar', 'mg road', 'mg road', 'delhi cantt.', 'nathan road', 'delhi university-gtb nagar', 'tiretti', 'nathan road', 'nathan road', 'fti college', 'd-block', 'delhi high court', 'd-block', 'sector 14', 'sector 14', 'fti college', 'sector 1', 'fti college', 'pune university', 'sector 1', 'd-block', 'sandhurst road', 'd-block', 'tejas nagar colony', 'rmz centennial', 'sandhurst road', 'chandni chowk', 'mg road', 'mg road', 'mg road', 'laxman vihar industrial area', 'delhi university-gtb nagar', 'delhi cantt.', 'majestic', 'delhi cantt.', 'sector 14', 'laxman vihar industrial area', 'd-block', 'majestic', 'delhi university-gtb nagar', 'mg road', 'sector 14', 'd-block', 'raja bazar', 'moulali', 'babarpur', 'mico layout', 'mico layout', 'delhi cantt.', 'majestic', 'd-block', 'sandhurst road', 'panjetan colony', 'majestic', 'sector 14', 'laxman vihar industrial area', 'sector 3', 'tiretti', 'pune university', 'sandhurst road', 'fti college', 'mico layout', 'moulali', 'mico layout', 'd-block', 'd-block', 'mg road', 'mumbai central', 'delhi university-gtb nagar', 'sandhurst road', 'delhi cantt.', 'd-block', 'delhi administration flats', 'mg road', 'mg road', 'delhi university-gtb nagar', 'fti college', 'sector 1', 'laxman vihar industrial area', 'mico layout', 'rmz centennial', 'mg road', 'sector 14', 'sector 63a', 'fti college', 'mico layout', 'chatta bazaar', 'sector 63a', 'rmz centennial', 'sector 14', 'raja bazar', 'mg road', 'moulali', 'yerawada', 'babarpur', 'delhi administration flats', 'mumbai central', 'raja bazar', 'dockyard road', 'chatta bazaar', 'sector 14', 'd-block', 'sector 3', 'sector 1', 'musi nagar', 'sector 1', 'babarpur', 'laxman vihar industrial area', 'secto ...

# %%
#Splitting Cuisines
cus_max = max_features_in_single_row(test['Cuisines'],train['Cuisines'], ',')
train_Cuisines_splits = feature_splitter(train['Cuisines'], 'Cuisines', ',', cus_max)
test_Cuisines_splits = feature_splitter(test['Cuisines'], 'Cuisines', ',', cus_max)
# Out:
#  -----------------------------------
# Max_Features in One Observation =  8
# -----------------------------------
# Features Dictionary :  {'Cuisines_Feature_1': [], 'Cuisines_Feature_2': [], 'Cuisines_Feature_3': [], 'Cuisines_Feature_4': [], 'Cuisines_Feature_5': [], 'Cuisines_Feature_6': [], 'Cuisines_Feature_7': [], 'Cuisines_Feature_8': []}
# 100%|█████████████████████████████████████████████████████████████████████████| 11094/11094 [00:00<00:00, 65112.32it/s]
# -----------------------------------
# Features Dictionary :  {'Cuisines_Feature_1': [], 'Cuisines_Feature_2': [], 'Cuisines_Feature_3': [], 'Cuisines_Feature_4': [], 'Cuisines_Feature_5': [], 'Cuisines_Feature_6': [], 'Cuisines_Feature_7': [], 'Cuisines_Feature_8': []}
# 100%|███████████████████████████████████████████████████████████████████████████| 2774/2774 [00:00<00:00, 86545.47it/s]

# %% [markdown]
# #### Rating, Votes & Reviews

# %% [markdown]
# We will now clean Rating, Votes & Reviews columns to remove invalid values and to convert them to the right type.

# %%
train.describe(include = 'all')
# Out:
#        Restaurant                                    Location      Cuisines  \
# count       11094                                       11094         11094
# unique       7480                                          35          2179
# top       ID_7184  Mico Layout, Stage 2, BTM Layout,Bangalore  North Indian
# freq           22                                         947           850
# mean          NaN                                         NaN           NaN
# std           NaN                                         NaN           NaN
# min           NaN                                         NaN           NaN
# 25%           NaN                                         NaN           NaN
# 50%           NaN                                         NaN           NaN
# 75%           NaN                                         NaN           NaN
# max           NaN                                         NaN           NaN
#
#        Average_Cost Minimum_Order Rating  Votes Reviews Delivery_Time  \
# count         11094         11094  11094  11094   11094         11094
# unique           26            18     33   1103     761             7
# top            ₹200           ₹50      -      -       -    30 minutes
# freq           3241         10118   1191   2074    2312          7406
# mean            NaN           NaN    NaN    NaN     NaN           NaN
# std             NaN           NaN    NaN    NaN     NaN           NaN
# min             NaN           NaN    NaN    NaN     NaN           NaN
# 25%             NaN           NaN    NaN    NaN     NaN           NaN
# 50%             NaN           NaN    NaN    NaN     NaN           NaN
# 75%             NaN           NaN    NaN    NaN     NaN           NaN
# max             NaN           NaN    NaN    NaN     NaN           NaN
#
#         Average_Cost_Cleaned  Minimum_Order_Cleaned
# count           11094.000000           11094.000000
# unique                   NaN                    NaN
# top                      NaN                    NaN
# freq                     NaN                    NaN
# mean              202.708671              53.344511
# std               129.833261              18.551245
# min                50.000000               0.000000
# 25%               100.000000              50.000000
# 50%               200.000000              50.000000
# 75%               200.000000              50.000000
# max              2050.000000             500.000000

# %%
#A function to find all the non numeric values
def non_numerals(series):
  non_numerals = []
  for i in series.unique():
    try :
      i = float(i)
    except:
      non_numerals.append(i)
  return non_numerals

# %%
# A function to replace the non-numeric values
def replace_nn_with(series, type_, fill_with = None, method = 'mean'):

  nn = non_numerals(series)
  print('-'*30)
  print('-'*30)
  print("Non Numerals in column ",series.name," : ",nn)

  series = series.replace(nn, np.nan, inplace = False)
  nulls = series.isnull().sum()
  if fill_with:
    series.fillna(fill_with, inplace = True)
    print("Filling Non Numerals with {}".format(fill_with))
  
  else:
    series = series.replace(nn, np.nan, inplace = False)

    if method == 'mean' :
      rep = series.astype(float).mean()
      print("Filling Non Numerals with MEAN = ", rep)

    elif method == 'median' :
      rep = series.astype(float).median()
      print("Filling Non Numerals with MEDIAN = ", rep)

    elif method == 'min' :
      rep = series.astype(float).min()
      print("Filling Non Numerals with MINIMUM = ", rep)

    else:
      print('Please pass a valid method as a string -- ("mean" or "median" or "min")')
      return 0

    series.fillna(rep, inplace = True)
    
  try:
    series = series.astype(type_)
    print(nulls, ": observations replaced")
    return series
  except:
    # Since type conversion of a string containting decimals to int is not possible, it is first converted to float
    series =  series.astype(float)
    print(nulls, ": observations replaced")
    series =  series.astype(type_)
    return series

# %%
train.head()
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
#
#                                  Cuisines Average_Cost Minimum_Order Rating  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps         ₹200           ₹50    3.5
# 1                     Ice Cream, Desserts         ₹100           ₹50    3.5
# 2         Italian, Street Food, Fast Food         ₹150           ₹50    3.6
# 3          Mughlai, North Indian, Chinese         ₹250           ₹99    3.7
# 4                         Cafe, Beverages         ₹200           ₹99    3.2
#
#   Votes Reviews Delivery_Time  Average_Cost_Cleaned  Minimum_Order_Cleaned
# 0    12       4    30 minutes                   200                     50
# 1    11       4    30 minutes                   100                     50
# 2    99      30    65 minutes                   150                     50
# 3   176      95    30 minutes                   250                     99
# 4   521     235    65 minutes                   200                     99

# %% [markdown]
# Lets Clean the columns

# %%
train['Rating_Cleaned'] = replace_nn_with(train['Rating'],float, method = 'mean')
# Out:
# ------------------------------
# ------------------------------
# Non Numerals in column  Rating  :  ['-', 'NEW', 'Opening Soon', 'Temporarily Closed']
# Filling Non Numerals with MEAN =  3.6134596429744827
# 1963 : observations replaced

# %%
test['Rating_Cleaned'] = replace_nn_with(test['Rating'],float, fill_with = 3.6134596429744668)
# Out:
# ------------------------------
# ------------------------------
# Non Numerals in column  Rating  :  ['NEW', '-', 'Opening Soon']
# Filling Non Numerals with 3.6134596429744668
# 507 : observations replaced

# %%
train['Votes_Cleaned'] = replace_nn_with(train['Votes'],int,method =  'mean')
# Out:
# ------------------------------
# ------------------------------
# Non Numerals in column  Votes  :  ['-']
# Filling Non Numerals with MEAN =  244.54445676274943
# 2074 : observations replaced

# %%
test['Votes_Cleaned'] = replace_nn_with(test['Votes'],int,fill_with = 244.54445676274943)
# Out:
# ------------------------------
# ------------------------------
# Non Numerals in column  Votes  :  ['-']
# Filling Non Numerals with 244.54445676274943
# 542 : observations replaced

# %%
train['Reviews_Cleaned'] = replace_nn_with(train['Reviews'],int, method =  'mean')
# Out:
# ------------------------------
# ------------------------------
# Non Numerals in column  Reviews  :  ['-']
# Filling Non Numerals with MEAN =  123.24789341835573
# 2312 : observations replaced

# %%
test['Reviews_Cleaned'] = replace_nn_with(test['Reviews'],int, method =  'mean',fill_with = 123.247893 )
# Out:
# ------------------------------
# ------------------------------
# Non Numerals in column  Reviews  :  ['-']
# Filling Non Numerals with 123.247893
# 593 : observations replaced

# %%
train.head(5)
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
#
#                                  Cuisines Average_Cost Minimum_Order Rating  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps         ₹200           ₹50    3.5
# 1                     Ice Cream, Desserts         ₹100           ₹50    3.5
# 2         Italian, Street Food, Fast Food         ₹150           ₹50    3.6
# 3          Mughlai, North Indian, Chinese         ₹250           ₹99    3.7
# 4                         Cafe, Beverages         ₹200           ₹99    3.2
#
#   Votes Reviews Delivery_Time  Average_Cost_Cleaned  Minimum_Order_Cleaned  \
# 0    12       4    30 minutes                   200                     50
# 1    11       4    30 minutes                   100                     50
# 2    99      30    65 minutes                   150                     50
# 3   176      95    30 minutes                   250                     99
# 4   521     235    65 minutes                   200                     99
#
#    Rating_Cleaned  Votes_Cleaned  Reviews_Cleaned
# 0             3.5             12                4
# 1             3.5             11                4
# 2             3.6             99               30
# 3             3.7            176               95
# 4             3.2            521              235

# %%
train.columns
# Out:
# Index(['Restaurant', 'Location', 'Cuisines', 'Average_Cost', 'Minimum_Order',
#        'Rating', 'Votes', 'Reviews', 'Delivery_Time', 'Average_Cost_Cleaned',
#        'Minimum_Order_Cleaned', 'Rating_Cleaned', 'Votes_Cleaned',
#        'Reviews_Cleaned'],
#       dtype='object')

# %% [markdown]
# We are done with the cleaning part and now we will select only the columns we need for further stages.

# %%
cols = ['Restaurant',  'Average_Cost_Cleaned',
       'Minimum_Order_Cleaned', 'Rating_Cleaned', 'Votes_Cleaned',
       'Reviews_Cleaned','Delivery_Time' ]

# %%
train_sample = train[cols]
test_sample = test[cols[:-1]]

# %% [markdown]
# We will now merge all the cleaned features to form a perfect dataframe

# %%
train_sample = pd.concat([pd.DataFrame(train_Location_splits), pd.DataFrame(train_Cuisines_splits),train_sample],sort=False,axis = 1)
test_sample = pd.concat([pd.DataFrame(test_Location_splits), pd.DataFrame(test_Cuisines_splits), test_sample],sort=False,axis = 1)

# %%
#lets take a look at the relation between the numeric features in the dataset
import seaborn
seaborn.pairplot(train_sample)

# %%
seaborn.pairplot(test_sample)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# After cleaning, there are still some Data-Preparation tasks left. We still have some missing values that we allotted during the feature generation.
#
# In the Preprocessing stage we will perform the following :
#
# * Dealing with Nulls/empty cells
# * Encoding Categorical variables
# * Scaling the features

# %% [markdown]
# ### Removing Nulls

# %%
train_sample.isnull().sum()
# Out:
# Location_Feature_1           0
# Location_Feature_2        1942
# Location_Feature_3        6364
# Location_Feature_4       10068
# Cuisines_Feature_1           0
# Cuisines_Feature_2        3012
# Cuisines_Feature_3        6931
# Cuisines_Feature_4        9393
# Cuisines_Feature_5       10449
# Cuisines_Feature_6       10854
# Cuisines_Feature_7       10978
# Cuisines_Feature_8       11046
# Restaurant                   0
# Average_Cost_Cleaned         0
# Minimum_Order_Cleaned        0
# Rating_Cleaned               0
# Votes_Cleaned                0
# Reviews_Cleaned              0
# Delivery_Time                0
# dtype: int64

# %% [markdown]
# Since the nulls are present only in the categorical features, in this approach, to make it simple I will just replace all the NaNs with a string 'NAN' and will use it as a added category or class.

# %%
train_sample.fillna('NAN', inplace = True)

# %%
train_sample.isnull().sum()
# Out:
# Location_Feature_1       0
# Location_Feature_2       0
# Location_Feature_3       0
# Location_Feature_4       0
# Cuisines_Feature_1       0
# Cuisines_Feature_2       0
# Cuisines_Feature_3       0
# Cuisines_Feature_4       0
# Cuisines_Feature_5       0
# Cuisines_Feature_6       0
# Cuisines_Feature_7       0
# Cuisines_Feature_8       0
# Restaurant               0
# Average_Cost_Cleaned     0
# Minimum_Order_Cleaned    0
# Rating_Cleaned           0
# Votes_Cleaned            0
# Reviews_Cleaned          0
# Delivery_Time            0
# dtype: int64

# %%
train_sample.isnull().sum()
# Out:
# Location_Feature_1       0
# Location_Feature_2       0
# Location_Feature_3       0
# Location_Feature_4       0
# Cuisines_Feature_1       0
# Cuisines_Feature_2       0
# Cuisines_Feature_3       0
# Cuisines_Feature_4       0
# Cuisines_Feature_5       0
# Cuisines_Feature_6       0
# Cuisines_Feature_7       0
# Cuisines_Feature_8       0
# Restaurant               0
# Average_Cost_Cleaned     0
# Minimum_Order_Cleaned    0
# Rating_Cleaned           0
# Votes_Cleaned            0
# Reviews_Cleaned          0
# Delivery_Time            0
# dtype: int64

# %%
test_sample.fillna('NAN', inplace = True)

# %%
train_sample.isnull().sum()
# Out:
# Location_Feature_1       0
# Location_Feature_2       0
# Location_Feature_3       0
# Location_Feature_4       0
# Cuisines_Feature_1       0
# Cuisines_Feature_2       0
# Cuisines_Feature_3       0
# Cuisines_Feature_4       0
# Cuisines_Feature_5       0
# Cuisines_Feature_6       0
# Cuisines_Feature_7       0
# Cuisines_Feature_8       0
# Restaurant               0
# Average_Cost_Cleaned     0
# Minimum_Order_Cleaned    0
# Rating_Cleaned           0
# Votes_Cleaned            0
# Reviews_Cleaned          0
# Delivery_Time            0
# dtype: int64

# %% [markdown]
# ### Encoding Categories

# %% [markdown]
# ---
#
# Here we will use a simple Label Encoder to transform all the strings or categories.

# %% [markdown]
# #### Locations & Cuisines

# %% [markdown]
# We will first find the unique values or categories in each of the categorical features and fit the label encoder with the unique values. The encoder will assign an integer code to each of the categories which can be used to tranform the entire categorical feature column.

# %%
temp1 = []
for i in train_Cuisines_splits.keys():
  for j in train_Cuisines_splits.get(i):
    temp1.append(j)

temp2 = []
for i in test_Cuisines_splits.keys():
  for j in test_Cuisines_splits.get(i):
    temp2.append(j)

temp1.extend(temp2)

unique_cuisines = list(pd.Series(temp1).unique())
unique_cuisines.append('NAN')

# %% [markdown]
# **Note:**
# We are also adding an extra category called NAN that we used to replace the NaN values.

# %%
len(unique_cuisines)
# Out:
# 103

# %% [markdown]
# The location is a tricky feature. You can use external data to fill the missing data. For example, if the city is missing you can use the street name and try to find the City for the missing fields.
#
# For simplicity, here I have followed the same approach as I did for Cuisines which is not a perfect solution.

# %%
temp1 = []
for i in train_Location_splits.keys():
  for j in train_Location_splits.get(i):
    temp1.append(j)

temp2 = []
for i in test_Location_splits.keys():
  for j in test_Location_splits.get(i):
    temp2.append(j)

temp1.extend(temp2)

unique_locations = list(pd.Series(temp1).unique())
unique_locations.append('NAN')

# %%
len(unique_locations)
# Out:
# 67

# %%
#encoding the categorical Features
from sklearn.preprocessing import LabelEncoder
le_c = LabelEncoder().fit(unique_cuisines)
le_l = LabelEncoder().fit(unique_locations)

# %%
for i in train_Location_splits.keys():
  train_sample[i] = le_l.transform(train_sample[i])

# %%
for i in train_Cuisines_splits.keys():
  train_sample[i] = le_c.transform(train_sample[i])

# %%
for i in train_Location_splits.keys():
  test_sample[i] = le_l.transform(test_sample[i])

# %%
for i in test_Cuisines_splits.keys():
  test_sample[i] = le_c.transform(test_sample[i])

# %% [markdown]
# #### Restaurant IDs

# %% [markdown]
# We will follow a similar approach for encoding the Restaurant IDs

# %%
t1 = list(train_sample['Restaurant'])
t2 = list(test_sample['Restaurant'])

t1.extend(t2)
unique_ids = list(set(t1))

# %%
len(unique_ids)
# Out:
# 8661

# %%
le_id = LabelEncoder().fit(unique_ids)

# %%
train_sample['Restaurant'] = le_id.transform(train_sample['Restaurant'])
test_sample['Restaurant'] = le_id.transform(test_sample['Restaurant'])

# %% [markdown]
# ### Scaling

# %% [markdown]
# We will now normalize the data using the StandardScaler

# %%
cols = list(train_sample.columns)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %%
train_sample[cols[:-1]] = ss.fit_transform(train_sample[cols[:-1]])

# %%
test_sample[cols[:-1]] = ss.fit_transform(test_sample[cols[:-1]])

# %%
train_sample.head()
# Out:
#    Location_Feature_1  Location_Feature_2  Location_Feature_3  \
# 0           -0.867166           -0.408678            1.683093
# 1            1.246323           -0.117669           -0.660441
# 2            0.242416           -1.669717           -0.660441
# 3            1.140649            0.415848           -0.660441
# 4            0.982137           -0.602684            2.580618
#
#    Location_Feature_4  Cuisines_Feature_1  Cuisines_Feature_2  \
# 0           -0.161374           -0.714599            1.656380
# 1           -0.161374           -0.312564           -0.125757
# 2           -0.161374           -0.129821            1.953402
# 3           -0.161374            0.637700            1.326354
# 4           -0.161374           -1.043537           -0.620795
#
#    Cuisines_Feature_3  Cuisines_Feature_4  Cuisines_Feature_5  \
# 0            0.137213            3.865914            7.460013
# 1           -0.621557           -0.359765           -0.205249
# 2            0.534663           -0.359765           -0.205249
# 3            0.354004           -0.359765           -0.205249
# 4           -0.621557           -0.359765           -0.205249
#
#    Cuisines_Feature_6  Cuisines_Feature_7  Cuisines_Feature_8  Restaurant  \
# 0           -0.125106            -0.08579           -0.057042    0.625956
# 1           -0.125106            -0.08579           -0.057042   -0.897145
# 2           -0.125106            -0.08579           -0.057042   -1.467013
# 3           -0.125106            -0.08579           -0.057042    0.451808
# 4           -0.125106            -0.08579           -0.057042    0.538284
#
#    Average_Cost_Cleaned  Minimum_Order_Cleaned  Rating_Cleaned  Votes_Cleaned  \
# 0             -0.020864              -0.180293       -0.301852      -0.464423
# 1             -0.791117              -0.180293       -0.301852      -0.466421
# 2             -0.405990              -0.180293       -0.035808      -0.290596
# 3              0.364263               2.461158        0.230235      -0.136749
# 4             -0.020864               2.461158       -1.099981       0.552564
#
#    Reviews_Cleaned Delivery_Time
# 0        -0.417345    30 minutes
# 1        -0.417345    30 minutes
# 2        -0.326311    65 minutes
# 3        -0.098724    30 minutes
# 4         0.391462    65 minutes

# %%
test_sample.head()
# Out:
#    Location_Feature_1  Location_Feature_2  Location_Feature_3  \
# 0            0.083713            1.243494           -0.479103
# 1            0.083713            1.243494           -0.479103
# 2            1.143599            0.416451           -0.673221
# 3           -1.665097            0.367801           -0.236455
# 4            1.143599            0.416451           -0.673221
#
#    Location_Feature_4  Cuisines_Feature_1  Cuisines_Feature_2  \
# 0            0.871523            0.809765           -0.204497
# 1            0.871523           -1.302905            0.628995
# 2           -0.151585           -0.746940           -1.104668
# 3           -0.151585            0.513250            1.362467
# 4           -0.151585           -0.932262           -0.037799
#
#    Cuisines_Feature_3  Cuisines_Feature_4  Cuisines_Feature_5  \
# 0           -0.346423           -0.351099           -0.196822
# 1           -0.605296           -0.351099           -0.196822
# 2           -0.605296           -0.351099           -0.196822
# 3            0.393217            1.259565            7.241203
# 4           -0.605296           -0.351099           -0.196822
#
#    Cuisines_Feature_6  Cuisines_Feature_7  Cuisines_Feature_8  Restaurant  \
# 0            -0.12173           -0.082445           -0.042516   -0.897086
# 1            -0.12173           -0.082445           -0.042516    1.096904
# 2            -0.12173           -0.082445           -0.042516   -0.101583
# 3            -0.12173           -0.082445           -0.042516    0.278454
# 4            -0.12173           -0.082445           -0.042516   -0.715119
#
#    Average_Cost_Cleaned  Minimum_Order_Cleaned  Rating_Cleaned  Votes_Cleaned  \
# 0              1.350471              -0.177278        1.612406       0.276837
# 1             -0.833142              -0.177278        0.029586       0.029087
# 2             -0.833142              -0.177278       -0.006736      -0.411358
# 3              0.040303              -0.177278       -0.006736      -0.347833
# 4             -0.396419              -0.177278       -1.895735      -0.407123
#
#    Reviews_Cleaned
# 0         0.428327
# 1         0.035125
# 2        -0.377352
# 3        -0.311818
# 4        -0.385062

# %% [markdown]
# ## Modeling

# %% [markdown]
# Finally, we are ready for modeling. We will split the training set into training and validation sets.
#
# We will then use the training set to train and validation set to test the performance of the model.
#
# Finally we will use the given test set for predicting.

# %%
from sklearn.model_selection import train_test_split

train, val = train_test_split(train_sample, test_size = 0.1, random_state = 123)

# %%
X_train = train[cols[:-1]]
Y_train = train[cols[-1]]

X_Val = val[cols[:-1]]
Y_Val = val[cols[-1]]

X_test = test_sample[cols[:-1]]

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import GridSearchCV
clf = DecisionTreeClassifier(random_state=0)

# %%
clf.fit(X_train,Y_train)
clf.score(X_Val,Y_Val)
# Out:
# 0.6954954954954955

# %%
param_grid = {
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(clf, param_grid, cv=5)
grid_search.fit(X_train, Y_train)
# Out:
# D:\Python\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=0),
#              param_grid={'max_depth': [3, 5, 7], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %%
best_dt = grid_search.best_estimator_
val_score = best_dt.score(X_Val, Y_Val)
print("Best Parameters:", grid_search.best_params_)
print("Validation Score:", val_score)
# Out:
# Best Parameters: {'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Validation Score: 0.7216216216216216

# %%
Predictions = best_dt.predict(X_test)

# %%
test_y_df = pd.DataFrame(Predictions, columns = ['Delivery_Time'])

# %%
test_y_df
# Out:
#      Delivery_Time
# 0       30 minutes
# 1       45 minutes
# 2       30 minutes
# 3       30 minutes
# 4       30 minutes
# ...            ...
# 2769    45 minutes
# 2770    30 minutes
# 2771    30 minutes
# 2772    30 minutes
# 2773    30 minutes
#
# [2774 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
Rforest = RandomForestClassifier()

# %%
Rforest.fit(X_train,Y_train)
Rforest.score(X_Val,Y_Val)
# Out:
# 0.7801801801801802

# %%
Predictions = Rforest.predict(X_test)

# %%
test_y_df = pd.DataFrame(Predictions, columns = ['Delivery_Time'])

# %%
test_y_df
# Out:
#      Delivery_Time
# 0       30 minutes
# 1       30 minutes
# 2       30 minutes
# 3       30 minutes
# 4       30 minutes
# ...            ...
# 2769    30 minutes
# 2770    30 minutes
# 2771    45 minutes
# 2772    30 minutes
# 2773    65 minutes
#
# [2774 rows x 1 columns]

# %%
from sklearn.svm import SVC
svm_model = SVC(kernel='rbf', C=1, gamma ="scale")
svm_model.fit(X_train, Y_train)

y_pred_train = svm_model.predict(X_train)
y_pred_val = svm_model.predict(X_Val)

# %%
accuracy = svm_model.score(X_Val, Y_Val)
print("Validation Accuracy: ", accuracy)
# Out:
# Validation Accuracy:  0.7036036036036036

# %%
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['rbf']
}
grid_search = GridSearchCV(svm_model, param_grid, refit=True, verbose=2, cv=5)

grid_search.fit(X_train, Y_train)

print("Best Parameters: ", grid_search.best_params_)
print("Best Score: ", grid_search.best_score_)

best_svc = grid_search.best_estimator_
accuracy = best_svc.score(X_Val, Y_Val)
print("Validation Accuracy: ", accuracy)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# D:\Python\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  18.9s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  19.4s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  18.6s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  20.1s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  18.6s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  11.6s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  10.8s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  12.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  11.5s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  10.9s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   9.3s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   9.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   9.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   9.8s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=  10.8s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   8.7s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   9.1s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   8.5s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   8.8s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   8.9s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  26.9s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  25.5s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  24.5s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  26.7s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  25.3s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  11.5s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  13.8s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  12.4s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  14.7s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  14.8s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=  13.6s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=  11.8s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=  10.9s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=  11.1s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=  10.8s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   9.2s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=  10.5s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=  10.3s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   9.3s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   9.5s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  26.8s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  29.5s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  26.5s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  27.6s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  26.8s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  14.8s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  15.7s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  15.4s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  14.5s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  14.5s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=  13.7s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=  15.1s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=  13.3s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=  13.4s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=  13.2s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=  11.9s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=  13.9s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=  12.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=  13.9s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=  12.7s
# Best Parameters:  {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# Best Score:  0.7084327392892946
# Validation Accuracy:  0.7198198198198198

# %%
file_path = r"C:\Users\91868\OneDrive\Desktop\DATA SCIENCE PROJECTS\New folder\Submission.xlsx"
pd.DataFrame(Predictions, columns=['Delivery_Time']).to_excel(file_path, index=False)
